# %% [markdown]
# # Admixture PLots

# %%
setwd('~/snap_hap_repHZ/Admixture/')

# %% [markdown]
# ## n86

# %%
admix2 = read.table('./admix/AvePla.stitch.SnpOnly.final.sorted.pruned.2.Q')
admix3 = read.table('./admix/AvePla.stitch.SnpOnly.final.sorted.pruned.3.Q')
admix4 = read.table('./admix/AvePla.stitch.SnpOnly.final.sorted.pruned.4.Q')
admix5 = read.table('./admix/AvePla.stitch.SnpOnly.final.sorted.pruned.5.Q')

# %%
options(repr.plot.width=12, repr.plot.height=12)

par(mfrow=c(4,1), cex.lab=1.5, mar=c(2,5,5,2))

barplot(t(admix2), space=0, yaxp=c(0,1,2), ylab='K = 2', col=c('cyan','red'))
axis(1, at=c(0,19,38,56,68,86), labels=FALSE, tck=-0.1)
axis(1, at=c(9.5,28.5,48,62,77), tick=FALSE, labels=c('Ye','FR','Ye','Hybrid','FR'), cex.axis=1.5)
axis(3, at=c(0,38,86), labels=FALSE, tck=-0.1)
axis(3, at=c(19,62), tick=FALSE, labels=c('Avellanet','Planoles'), cex.axis=1.5)

barplot(t(admix3), space=0, yaxp=c(0,1,2), ylab='K = 3', col=c('red','magenta1','gold1'))
axis(1, at=c(0,19,38,56,68,86), labels=FALSE, tck=-0.1)
axis(1, at=c(9.5,28.5,48,62,77), tick=FALSE, labels=c('Ye','FR','Ye','Hybrid','FR'), cex.axis=1.5)
axis(3, at=c(0,38,86), labels=FALSE, tck=-0.1)
axis(3, at=c(19,62), tick=FALSE, labels=c('Avellanet','Planoles'), cex.axis=1.5)

barplot(t(admix4), space=0, yaxp=c(0,1,2), ylab='K = 4', col=c('gold1','magenta3','magenta1','gold3'))
axis(1, at=c(0,19,38,56,68,86), labels=FALSE, tck=-0.1)
axis(1, at=c(9.5,28.5,48,62,77), tick=FALSE, labels=c('Ye','FR','Ye','Hybrid','FR'), cex.axis=1.5)
axis(3, at=c(0,38,86), labels=FALSE, tck=-0.1)
axis(3, at=c(19,62), tick=FALSE, labels=c('Avellanet','Planoles'), cex.axis=1.5)

barplot(t(admix5), space=0, yaxp=c(0,1,2), ylab='K = 5', col=c('yellow1','magenta1','khaki3','magenta3','gold3'))
axis(1, at=c(0,19,38,56,68,86), labels=FALSE, tck=-0.1)
axis(1, at=c(9.5,28.5,48,62,77), tick=FALSE, labels=c('Ye','FR','Ye','Hybrid','FR'), cex.axis=1.5)
axis(3, at=c(0,38,86), labels=FALSE, tck=-0.1)
axis(3, at=c(19,62), tick=FALSE, labels=c('Avellanet','Planoles'), cex.axis=1.5)
# Out:
# plot without title

# %% [markdown]
# ## n74 samples, without Pla-Hybrid

# %%
admix2 = read.table('./admix/AvePla.FrYe.stitch.SnpOnly.final.sorted.pruned.2.Q')
admix3 = read.table('./admix/AvePla.FrYe.stitch.SnpOnly.final.sorted.pruned.3.Q')
admix4 = read.table('./admix/AvePla.FrYe.stitch.SnpOnly.final.sorted.pruned.4.Q')
admix5 = read.table('./admix/AvePla.FrYe.stitch.SnpOnly.final.sorted.pruned.5.Q')

# %%
samples = read.table('~/snap_hap_repHZ/samples/samples.AvePla.FrYe.n74.sortedLong.info', header=T)
str(samples)
# Out:
# 'data.frame':	74 obs. of  8 variables:
#  $ PlantID    : chr  "n96_Am_Pla_z2711_v3.5" "n96_Am_Pla_z2008_v3.5" "n96_Am_Pla_z0347_v3.5" "n96_Am_Pla_z3891_v3.5" ...
#  $ FlowerColor: chr  "Y" "Y" "Y" "Y" ...
#  $ Pool       : chr  "Pla_Y" "Pla_Y" "Pla_Y" "Pla_Y" ...
#  $ HZ         : chr  "Pla" "Pla" "Pla" "Pla" ...
#  $ ID         : int  67 63 58 68 65 73 71 69 59 70 ...
#  $ Long       : num  2.06 2.06 2.06 2.06 2.06 ...
#  $ Color_Pool : chr  "blue" "blue" "blue" "blue" ...
#  $ Color_HZ   : chr  "red" "red" "red" "red" ...

# %%
# admix2[samples$ID,]

# %%
options(repr.plot.width=12, repr.plot.height=12)

par(mfrow=c(4,1), cex.lab=2, mar=c(2.5,5,5,2))

barplot(t(admix2[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 2', col=c('cyan','red'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('','','',''), cex.axis=1.5)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('Planoles','Avellanet'), cex.axis=2)

barplot(t(admix3[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 3', col=c('red','yellow','magenta'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('','','',''), cex.axis=1.5)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('',''), cex.axis=1.5)

barplot(t(admix4[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 4', col=c('magenta','gold3','yellow','magenta3'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('','','',''), cex.axis=1.5)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('',''), cex.axis=1.5)

barplot(t(admix5[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 5', col=c('magenta','yellow','orange','gold3','magenta3'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('Yellow','Magenta','Yellow','Magenta'), cex.axis=2)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('',''), cex.axis=1.5)
# Out:
# plot without title

# %%
pdf(file = './AdmixturePlots_n74.pdf', height=12, width=12)

par(mfrow=c(4,1), cex.lab=2, mar=c(2.5,5,5,2))

barplot(t(admix2[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 2', col=c('cyan','red'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('','','',''), cex.axis=1.5)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('Planoles','Avellanet'), cex.axis=2)

barplot(t(admix3[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 3', col=c('red','yellow','magenta'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('','','',''), cex.axis=1.5)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('',''), cex.axis=1.5)

barplot(t(admix4[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 4', col=c('magenta','gold3','yellow','magenta3'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('','','',''), cex.axis=1.5)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('',''), cex.axis=1.5)

barplot(t(admix5[samples$ID,]), space=0, yaxp=c(0,1,2), ylab='K = 5', col=c('magenta','yellow','orange','gold3','magenta3'), xaxt='n')
axis(1, at=c(0,18,36,55,74), labels=FALSE, tck=-0.1)
axis(1, at=c(9,27,45.5,64.5), tick=FALSE, labels=c('Yellow','Magenta','Yellow','Magenta'), cex.axis=2)
axis(3, at=c(0,36,74), labels=FALSE, tck=-0.1)
axis(3, at=c(18,55), tick=FALSE, labels=c('',''), cex.axis=1.5)

dev.off()
# Out:
# png
#   2
